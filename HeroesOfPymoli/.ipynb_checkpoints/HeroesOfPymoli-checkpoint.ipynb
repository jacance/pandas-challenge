# %% [markdown]
# ### Heroes Of Pymoli

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
data_file = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(data_file)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
# Total number of unique players

total_players = purchase_data["SN"].nunique()
total_players
total_players_df = pd.DataFrame({"Total Players": [total_players]})
total_players_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Number of unique items

unique_items = len(purchase_data["Item Name"].unique())
unique_items
# Out:
# 179

# %%
# Average purchase price (mean of price)

avg_price = purchase_data["Price"].mean()
avg_price
# Out:
# 3.050987179487176

# %%
# Number of purchases

purchases = purchase_data["Purchase ID"].count()
purchases
# Out:
# 780

# %%
# Total Revenue (sum of price)

total_revenue = purchase_data["Price"].sum()
total_revenue
# Out:
# 2379.77

# %%
# Purchasing analysis dataframe number of unique items, average price, number of purchases, and total revenue.

purchasing_analysis = pd.DataFrame({
    "Number of Unique Items": [unique_items],
    "Average Price": [avg_price],
    "Number of Purchases": [purchases],
    "Total Revenue": [total_revenue]
})

# Format average price and total revenue as currency
purchasing_analysis["Average Price"] = purchasing_analysis["Average Price"].map("${:.2f}".format)
purchasing_analysis["Total Revenue"] = purchasing_analysis["Total Revenue"].map("${:.2f}".format)
purchasing_analysis
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780      $2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# Create dataframe without duplicate players
gender_df = purchase_data.loc[:,["SN","Gender"]]
gender_reduced = gender_df.drop_duplicates(subset=["SN"])

# Count of each gender
gender_only_count = gender_reduced["Gender"].value_counts()
gender_only_count

# Percentage of players by gender
gender_percentage = gender_only_count/total_players*100

# %%
# Dataframe with total count and percentage of players by gender
gender_analysis_df = pd.DataFrame({
    "Total Count": gender_only_count,
    "Percentage of Players": gender_percentage
})

# Format percentage of players by gender
gender_analysis_df["Percentage of Players"] = gender_analysis_df["Percentage of Players"].map("{:.2f}%".format)

gender_analysis_df
# Out:
#                        Total Count Percentage of Players
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Create list to only show Gender and Price columns
gender_prices_list = ['Gender', 'Price']


# Purchase count by gender
gender_purchase_count = purchase_data[gender_prices_list].groupby(['Gender']).count()
gender_purchase_count = gender_purchase_count.rename(columns={"Price": "Purchase Count"})
gender_purchase_count
# Out:
#                        Purchase Count
# Gender
# Female                            113
# Male                              652
# Other / Non-Disclosed              15

# %%
# Average Purchase Price by gender
avg_gender_price = purchase_data[gender_prices_list].groupby(['Gender']).mean()
avg_gender_price = avg_gender_price.rename(columns={"Price": "Average Purchase Price"})

# Format prices
avg_gender_price["Average Purchase Price"] = avg_gender_price["Average Purchase Price"].map("${:.2f}".format)
avg_gender_price
# Out:
#                       Average Purchase Price
# Gender
# Female                                 $3.20
# Male                                   $3.02
# Other / Non-Disclosed                  $3.35

# %%
# Total Purchase Value by gender
total_gender_value = purchase_data[gender_prices_list].groupby(['Gender']).sum()
total_gender_value = total_gender_value.rename(columns={"Price": "Total Purchase Value"})

total_gender_value
# Out:
#                        Total Purchase Value
# Gender
# Female                               361.94
# Male                                1967.64
# Other / Non-Disclosed                 50.19

# %%
# Average Total Purchase per Person

# Female average total purchase
female_total_purchase = total_gender_value.iloc[0, 0]
female_average = female_total_purchase / gender_analysis_df.iloc[1,0]

# Male average total purchase
male_total_purchase = total_gender_value.iloc[1, 0]
male_average = male_total_purchase / gender_analysis_df.iloc[0,0]
male_average

# Other / Non-Disclosed average total purchase
other_total_purchase = total_gender_value.iloc[2, 0]
other_average = other_total_purchase / gender_analysis_df.iloc[2,0]

# Dataframe of average total purchase by gender
average_purchase_person = pd.DataFrame({"Gender": ["Female", "Male", "Other / Non-Disclosed"],
                                        "Avg Total Purchase per Person":[female_average, male_average, other_average]})

average_purchase_person["Avg Total Purchase per Person"] = average_purchase_person["Avg Total Purchase per Person"].map("${:.2f}".format)
average_purchase_person
# Out:
#                   Gender Avg Total Purchase per Person
# 0                 Female                         $4.47
# 1                   Male                         $4.07
# 2  Other / Non-Disclosed                         $4.56

# %%
# Merged purchasing analysis by gender into one dataframe

merged1 = pd.merge(gender_purchase_count, avg_gender_price, on="Gender", how="left")
merged2 = pd.merge(merged1, total_gender_value, on="Gender", how="left")
gender_analytics_df = pd.merge(merged2, average_purchase_person, on="Gender", how="left")

# Format Total Purchase Value
gender_analytics_df["Total Purchase Value"] = gender_analytics_df["Total Purchase Value"].map("${:.2f}".format)
gender_analytics_df.set_index("Gender")
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                              $1967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Create age groups and bins for data

group_ages = [
    "<10",
    "10-14",
    "15-19",
    "20-24",
    "25-29",
    "30-34",
    "35-39",
    "40+"]

bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 100]

# %%
# Dataframe for age with no duplicate players
age_df = purchase_data.loc[:,["SN","Age"]]
age_df = age_df.drop_duplicates(subset=["SN"])

# Add Age Ranges column to dataframe
age_df["Age Ranges"] = pd.cut(age_df.Age, bins, labels = group_ages, include_lowest=True)
age_df.head()

# Divide value counts of age groups by the number of total players to get percentage
age_group_counts = age_df["Age Ranges"].value_counts()
age_percentage = age_group_counts / total_players * 100

# %%
# Create dataframe using dictionary then format percentage of players.
age_demographics = pd.DataFrame({"Total Count": age_group_counts,
                                "Percentage of Players": age_percentage})

# Format to percentage
age_demographics["Percentage of Players"] = age_demographics["Percentage of Players"].map("{:.2f}%".format)

# Sort age group by ascending order
age_demographics.sort_index(axis=0)
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Create age groups and bins for purchase data

group_ages = [
    "<10",
    "10-14",
    "15-19",
    "20-24",
    "25-29",
    "30-34",
    "35-39",
    "40+"]

bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 100]

# %%
# Dataframe of age and price
age_purchase = purchase_data.loc[:,["Age", "Price"]]

# Add age range column and bin rows by age
age_purchase["Age Ranges"] = pd.cut(age_purchase.Age, bins, labels = group_ages, include_lowest=True)

# Count of purchases by age range
age_purchase_count = age_purchase["Age Ranges"].value_counts()

# Sort by age ranges
# age_purchase_count = age_purchase_count.sort_index(axis=0)

# Average purchase price by age range
avg_age_price = age_purchase.groupby(['Age Ranges']).mean()
avg_age_price = avg_age_price["Price"]

# %%
# Total purchase value by age range
age_total_purchase = age_purchase.groupby(['Age Ranges']).sum()
age_total_purchase = age_total_purchase["Price"]
age_total_purchase
# Out:
# Age Ranges
# <10        77.13
# 10-14      82.78
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     147.67
# 40+        38.24
# Name: Price, dtype: float64

# %%
# Divide total purchase counts by age group count to get average total purchase per person
age_avg_total_purchase_pp = age_total_purchase / age_group_counts
age_avg_total_purchase_pp
# Out:
# <10      4.537059
# 10-14    3.762727
# 15-19    3.858785
# 20-24    4.318062
# 25-29    3.805195
# 30-34    4.115385
# 35-39    4.763548
# 40+      3.186667
# dtype: float64

# %%
# Create dataframe with purchase count, average purchase price, total purchase value, and aaverage total purchase per person
age_purchase_analysis_df = pd.DataFrame({
    "Age Ranges": group_ages,
    "Purchase Count": age_purchase_count,
    "Average Purchase Price": avg_age_price,
    "Total Purchase Value": age_total_purchase,
    "Avg Total Purchase per Person": age_avg_total_purchase_pp
})

# Count how many people are in each age group and convert to percentage
age_group_counts = age_df["Age Ranges"].value_counts()
age_percentage = age_group_counts / total_players * 100


# Format prices
age_purchase_analysis_df["Average Purchase Price"] = age_purchase_analysis_df["Average Purchase Price"].map("${:.2f}".format)
age_purchase_analysis_df["Total Purchase Value"] = age_purchase_analysis_df["Total Purchase Value"].map("${:.2f}".format)
age_purchase_analysis_df["Avg Total Purchase per Person"] = age_purchase_analysis_df["Avg Total Purchase per Person"].map("${:.2f}".format)


# Set group ages as index
age_purchase_analysis_df = age_purchase_analysis_df.set_index('Age Ranges')
age_purchase_analysis_df
# Out:
#             Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                     23                  $3.35               $77.13
# 10-14                   28                  $2.96               $82.78
# 15-19                  136                  $3.04              $412.89
# 20-24                  365                  $3.05             $1114.06
# 25-29                  101                  $2.90              $293.00
# 30-34                   73                  $2.93              $214.00
# 35-39                   41                  $3.60              $147.67
# 40+                     13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Group by SN to find top spenders
top_spenders = purchase_data.loc[:,["Purchase ID","SN","Price"]]
top_spenders_grouped = top_spenders.groupby("SN")
top_spenders_grouped.count()
# Out:
#                Purchase ID  Price
# SN
# Adairialis76             1      1
# Adastirin33              1      1
# Aeda94                   1      1
# Aela59                   1      1
# Aelaria33                1      1
# ...                    ...    ...
# Yathecal82               3      3
# Yathedeu43               2      2
# Yoishirrala98            1      1
# Zhisrisu83               2      2
# Zontibe81                3      3
#
# [576 rows x 2 columns]

# %%
# Count top spenders
top_spenders_count = top_spenders_grouped["Purchase ID"].count()

# Get total purchase value by users
sum_user_price = top_spenders_grouped["Price"].sum()

# Average user purchase price
average_user_price = sum_user_price / top_spenders_count

# Dataframe of top spenders
top_spenders_summary = pd.DataFrame({
    "Purchase Count": top_spenders_count,
    "Average Purchase Price": average_user_price,
    "Total Purchase Value": sum_user_price})

top_spenders_summary
# Out:
#                Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Adairialis76                1                2.280000                  2.28
# Adastirin33                 1                4.480000                  4.48
# Aeda94                      1                4.910000                  4.91
# Aela59                      1                4.320000                  4.32
# Aelaria33                   1                1.790000                  1.79
# ...                       ...                     ...                   ...
# Yathecal82                  3                2.073333                  6.22
# Yathedeu43                  2                3.010000                  6.02
# Yoishirrala98               1                4.580000                  4.58
# Zhisrisu83                  2                3.945000                  7.89
# Zontibe81                   3                2.676667                  8.03
#
# [576 rows x 3 columns]

# %%
# Sort by Total Purchase Value to find top spenders
sorted_top_spenders_summary = top_spenders_summary.sort_values(["Total Purchase Value"],ascending = False)

# Format prices
sorted_top_spenders_summary["Average Purchase Price"] = sorted_top_spenders_summary["Average Purchase Price"].map("${:.2f}".format)
sorted_top_spenders_summary["Total Purchase Value"] = sorted_top_spenders_summary["Total Purchase Value"].map("${:.2f}".format)

sorted_top_spenders_summary.head()
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Get count of items grouped by name
items_df = purchase_data.loc[:,["Item ID","Item Name","Price"]]
grouped_items = items_df.groupby(["Item ID","Item Name"])
grouped_items.count()
# Out:
#                                                       Price
# Item ID Item Name
# 0       Splinter                                          4
# 1       Crucifer                                          4
# 2       Verdict                                           6
# 3       Phantomlight                                      6
# 4       Bloodlord's Fetish                                5
# ...                                                     ...
# 178     Oathbreaker, Last Hope of the Breaking Storm     12
# 179     Wolf, Promise of the Moonwalker                   6
# 181     Reaper's Toll                                     5
# 182     Toothpick                                         3
# 183     Dragon's Greatsword                               3
#
# [179 rows x 1 columns]

# %%
# Count most popular items
item_counts = grouped_items["Item Name"].count()

# Sum item prices for total purchase value
total_price_item = grouped_items["Price"].sum()

# Get item prices
item_price = total_price_item / item_counts

# Dataframe for most popular items
most_popular_items = pd.DataFrame({
    "Purchase Count": item_counts,
    "Item Price": item_price,
    "Total Purchase Value": total_price_item
})

most_popular_items
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 0       Splinter                                                   4
# 1       Crucifer                                                   4
# 2       Verdict                                                    6
# 3       Phantomlight                                               6
# 4       Bloodlord's Fetish                                         5
# ...                                                              ...
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 179     Wolf, Promise of the Moonwalker                            6
# 181     Reaper's Toll                                              5
# 182     Toothpick                                                  3
# 183     Dragon's Greatsword                                        3
#
#                                                       Item Price  \
# Item ID Item Name
# ...

# %%
# Sort by Purchase Count to find most popular items
sorted_most_popular_items = most_popular_items.sort_values("Purchase Count",ascending=False)

# Format prices
sorted_most_popular_items["Item Price"] = sorted_most_popular_items["Item Price"].map("${:.2f}".format)
sorted_most_popular_items["Total Purchase Value"] = sorted_most_popular_items["Total Purchase Value"].map("${:.2f}".format)

sorted_most_popular_items.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Sort by Total Purchase Value to find most profitable items
sorted_most_profitable_items = most_popular_items.sort_values("Total Purchase Value",ascending=False)

# Format prices
sorted_most_profitable_items["Item Price"] = sorted_most_profitable_items["Item Price"].map("${:.2f}".format)
sorted_most_profitable_items["Total Purchase Value"] = sorted_most_profitable_items["Total Purchase Value"].map("${:.2f}".format)
sorted_most_profitable_items.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# # Observed trends:
#
# - Players are predominantly male and make up 84.03% of the total player base.
#
# - With an average item purchase price of $4.56, players who choose not to disclose their gender tend to spend more than Males and Females.
#
# - Nearly half of all players (44.79%) are between the ages of 20-24. The average purchase price of items by these players is $4.32.
